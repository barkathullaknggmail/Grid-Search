# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
dataset=pd.read_csv("insurance_pre.csv")
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True)
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400     False        True
# 1      18  33.770         1   1725.55230      True       False
# 2      28  33.000         3   4449.46200      True       False
# 3      33  22.705         0  21984.47061      True       False
# 4      32  28.880         0   3866.85520      True       False
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830      True       False
# 1334   18  31.920         0   2205.98080     False       False
# 1335   18  36.850         0   1629.83350     False       False
# 1336   21  25.800         0   2007.94500     False       False
# 1337   61  29.070         0  29141.36030     False        True
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]
independent
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0     False        True
# 1      18  33.770         1      True       False
# 2      28  33.000         3      True       False
# 3      33  22.705         0      True       False
# 4      32  28.880         0      True       False
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3      True       False
# 1334   18  31.920         0     False       False
# 1335   18  36.850         0     False       False
# 1336   21  25.800         0     False       False
# 1337   61  29.070         0     False        True
#
# [1338 rows x 5 columns]

# %%
dependent=dataset[['charges']]
dependent
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import GridSearchCV
param_grid = {'criterion':['squared_error','absolute_error','friedman_mse','poisson'],
             'max_features':[None,'sqrt','log2'],
              'splitter':['best','random']}
grid = GridSearchCV(DecisionTreeRegressor(), param_grid, refit = True, verbose = 3,n_jobs=-1)
# fitting the model for grid search
grid.fit(independent,dependent)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute_error',
#                                        'friedman_mse', 'poisson'],
#                          'max_features': [None, 'sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
# print best parameter after tunng
# print(grid.best_params_)
re = grid.cv_results_
# print(re)
print("The r_value for best parameter{}:".format(grid.best_params_))
# Out:
# The r_value for best parameter{'criterion': 'poisson', 'max_features': None, 'splitter': 'best'}:

# %%
table=pd.DataFrame.from_dict(re)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.025892      0.009174         0.018989    1.416163e-02
# 1        0.013145      0.004864         0.010994    9.027740e-03
# 2        0.014590      0.005459         0.009795    6.611319e-03
# 3        0.015722      0.011906         0.010563    8.663956e-03
# 4        0.013991      0.006030         0.010194    8.902358e-03
# 5        0.014815      0.006023         0.007371    3.270580e-03
# 6        0.137043      0.019043         0.006196    4.004246e-04
# 7        0.077351      0.008400         0.018789    1.587021e-02
# 8        0.066306      0.010429         0.007397    1.199865e-03
# 9        0.050726      0.003728         0.006838    1.211475e-03
# 10       0.064759      0.011747         0.012193    9.940960e-03
# 11       0.036176      0.001938         0.005798    3.999473e-04
# 12       0.013901      0.000808         0.006796    9.787126e-04
# 13       0.009792      0.000400         0.006797    1.165460e-03
# 14       0.010592      0.000490         0.006197    3.997329e-04
# 15       0.009393      0.000490         0.005997    2.431402e-07
# 16       0.010992      0.000632         0.005798    4.006865e-04
# 17       0.009593      0.000800         0.006597    1.355707e-03
# 18       0.020295      0.001678         0.006397    4.897458e-04
# 19       0.015189      0.000400         0.005997    7.448435e-07
# 20       0.017388      0.000800         0.005997    3.234067e-07
# 21       0.015589      0.001853         0.005997    6.324098e-04
# 22       0.016603      0.000808         0.005782    3.932241e-04
# 23       0.014789      0.000748         0.006597    7.994295e-04
#
#    param_criterion param_max_features param_splitter  \
# 0    squared_error               None           best
# 1    squared_error               None         random
# 2    squared_error               sqrt           best
# 3    squared_error               sqrt         random
# 4    squared_error               log2           best
# 5    squared_error               log2         random
# 6   absolute_error               None           best
# 7   absolute_error               None         random
# 8   absolute_error               sqrt           best
# 9   absolute_error               sqrt         random
# 10  absolute_error               log2           best
# 11  absolute_error               log2         random
# 12    friedman_mse               None           best
# 13    friedman_mse               None         random
# 14    friedman_mse               sqrt           best
# 15    friedman_mse               sqrt         random
# 16    friedman_mse               log2           best
# 17    friedman_mse               log2         random
# 18         poisson               None           best
# 19         poisson               None         random
# 20         poisson               sqrt           best
# 21         poisson               sqrt         random
# 22         poisson               log2           best
# 23         poisson               log2         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.715105
# 1   {'criterion': 'squared_error', 'max_features':...           0.725780
# 2   {'criterion': 'squared_error', 'max_features':...           0.646202
# 3   {'criterion': 'squared_error', 'max_features':...           0.652430
# 4   {'criterion': 'squared_error', 'max_features':...           0.713230
# 5   {'criterion': 'squared_error', 'max_features':...           0.643759
# 6   {'criterion': 'absolute_error', 'max_features'...           0.725917
# 7   {'criterion': 'absolute_error', 'max_features'...           0.699933
# 8   {'criterion': 'absolute_error', 'max_features'...           0.753016
# 9   {'criterion': 'absolute_error', 'max_features'...           0.584106
# 10  {'criterion': 'absolute_error', 'max_features'...           0.700592
# 11  {'criterion': 'absolute_error', 'max_features'...           0.608039
# 12  {'criterion': 'friedman_mse', 'max_features': ...           0.712661
# 13  {'criterion': 'friedman_mse', 'max_features': ...           0.681000
# 14  {'criterion': 'friedman_mse', 'max_features': ...           0.729875
# 15  {'criterion': 'friedman_mse', 'max_features': ...           0.706124
# 16  {'criterion': 'friedman_mse', 'max_features': ...           0.734325
# 17  {'criterion': 'friedman_mse', 'max_features': ...           0.706794
# 18  {'criterion': 'poisson', 'max_features': None,...           0.742379
# 19  {'criterion': 'poisson', 'max_features': None,...           0.663018
# 20  {'criterion': 'poisson', 'max_features': 'sqrt...           0.679418
# 21  {'criterion': 'poisson', 'max_features': 'sqrt...           0.713577
# 22  {'criterion': 'poisson', 'max_features': 'log2...           0.631721
# 23  {'criterion': 'poisson', 'max_features': 'log2...           0.693277
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.654615           0.718090           0.700046
# 1            0.573366           0.732941           0.730207
# 2            0.649046           0.701838           0.690140
# 3            0.619619           0.700822           0.711460
# 4            0.538412           0.760046           0.557607
# 5            0.572233           0.713543           0.669759
# 6            0.582923           0.689902           0.719047
# 7            0.661721           0.732653           0.683203
# 8            0.599625           0.532339           0.691024
# 9            0.664048           0.603310           0.692934
# 10           0.592178           0.560486           0.721025
# 11           0.545779           0.532382           0.738016
# 12           0.646814           0.729329           0.739372
# 13           0.659592           0.618836           0.748917
# 14           0.611262           0.714961           0.668524
# 15           0.640794           0.679363           0.638841
# 16           0.641885           0.736605           0.675080
# 17           0.529155           0.729371           0.664446
# 18           0.671601           0.767723           0.719591
# 19           0.542600           0.710362           0.705366
# 20           0.626795           0.718808           0.527005
# 21           0.511522           0.685624           0.655741
# 22           0.621098           0.685058           0.690394
# 23           0.510753           0.535194           0.725620
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.696265         0.696824        0.022710                7
# 1            0.731063         0.698671        0.062697                5
# 2            0.673099         0.672065        0.021968               13
# 3            0.685375         0.673941        0.033689               11
# 4            0.728281         0.659515        0.092490               16
# 5            0.698484         0.659555        0.049818               15
# 6            0.760147         0.695587        0.060603                8
# 7            0.759213         0.707345        0.034785                2
# 8            0.761667         0.667534        0.089005               14
# 9            0.664063         0.641692        0.041025               22
# 10           0.722664         0.659389        0.068992               17
# 11           0.652952         0.615434        0.075151               24
# 12           0.680122         0.701660        0.034002                4
# 13           0.709550         0.683579        0.044084                9
# 14           0.762789         0.697482        0.052711                6
# 15           0.609238         0.654872        0.033953               19
# 16           0.725446         0.702668        0.037758                3
# 17           0.653396         0.656632        0.069468               18
# 18           0.690417         0.718342        0.034590                1
# 19           0.740265         0.672322        0.069382               12
# 20           0.666781         0.643762        0.065350               21
# 21           0.687661         0.650825        0.072021               20
# 22           0.743854         0.674425        0.044398               10
# 23           0.653006         0.623570        0.085648               23

# %%
age=float(input("AGE:"))
bmi=float(input("BMI:"))
children=float(input("Children:"))
gender=int(input("Gender Male 0 or 1:"))
smoker=int(input("Smoker Yes 0 or 1 :"))
# Out:
# AGE: 32
# BMI: 43
# Children: 2
# Gender Male 0 or 1: 0
# Smoker Yes 0 or 1 : 1

# %%
Prediction=grid.predict([[age,bmi,children,gender,smoker]])
print("Future Predocion{}".format(Prediction))
# Out:
# Future Predocion[40932.4295]
# C:\Anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(

# %%
Prediction=grid.predict([[32,43,2,0,1]])
Prediction
# Out:
# C:\Anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# array([40932.4295])
