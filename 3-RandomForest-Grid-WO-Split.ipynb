# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
dataset=pd.read_csv("insurance_pre.csv")
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True)
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400     False        True
# 1      18  33.770         1   1725.55230      True       False
# 2      28  33.000         3   4449.46200      True       False
# 3      33  22.705         0  21984.47061      True       False
# 4      32  28.880         0   3866.85520      True       False
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830      True       False
# 1334   18  31.920         0   2205.98080     False       False
# 1335   18  36.850         0   1629.83350     False       False
# 1336   21  25.800         0   2007.94500     False       False
# 1337   61  29.070         0  29141.36030     False        True
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]
independent
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0     False        True
# 1      18  33.770         1      True       False
# 2      28  33.000         3      True       False
# 3      33  22.705         0      True       False
# 4      32  28.880         0      True       False
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3      True       False
# 1334   18  31.920         0     False       False
# 1335   18  36.850         0     False       False
# 1336   21  25.800         0     False       False
# 1337   61  29.070         0     False        True
#
# [1338 rows x 5 columns]

# %%
dependent=dataset[['charges']]
dependent
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
param_grid = {'criterion':['squared_error','absolute_error','friedman_mse','poisson'],
             'max_features':[None,'sqrt','log2'],
              'n_estimators':[10,100]}
grid = GridSearchCV(RandomForestRegressor(), param_grid, refit = True, verbose = 3,n_jobs=-1)
# fitting the model for grid search
grid.fit(independent,dependent)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# C:\Anaconda3\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute_error',
#                                        'friedman_mse', 'poisson'],
#                          'max_features': [None, 'sqrt', 'log2'],
#                          'n_estimators': [10, 100]},
#              verbose=3)

# %%
# print best parameter after tunng
# print(grid.best_params_)
re = grid.cv_results_
print(re)
print("The r_value for best parameter{}:".format(grid.best_params_))
# Out:
# {'mean_fit_time': array([0.09240217, 0.81633697, 0.07455349, 0.63088012, 0.08505921,
#        0.60917487, 0.35156603, 3.65408797, 0.25064449, 2.15433784,
#        0.21866026, 2.38609624, 0.13137379, 0.88634624, 0.08054962,
#        0.65403929, 0.06975574, 0.79797678, 0.20487552, 1.89317904,
#        0.22336836, 1.39242344, 0.17817979, 1.57275205]), 'std_fit_time': array([0.0035407 , 0.01000517, 0.00135546, 0.0303039 , 0.01646445,
#        0.00721874, 0.00556407, 0.0347743 , 0.03199522, 0.03234806,
#        0.00718366, 0.1401752 , 0.03756966, 0.0268538 , 0.00531096,
#        0.01794511, 0.00171872, 0.11797124, 0.02153927, 0.0493513 ,
#        0.0560676 , 0.02346765, 0.01987949, 0.14662655]), 'mean_score_time': array([0.00992427, 0.02918291, 0.01099377, 0.02674217, 0.00915966,
#        0.025385  , 0.00859523, 0.02855234, 0.00859447, 0.0280818 ,
#        0.00957189, 0.03437023, 0.00819478, 0.03048029, 0.01239305,
#        0.0288897 , 0.00899549, 0.06214709, 0.00947714, 0.04253163,
#        0.01279178, 0.04377275, 0.0151906 , 0.04127684]), 'std_score_time': array([6.47724468e-04, 3.18535661e-03, 2.09653371e-03, 7.32169931e-04,
#        4.22959306e-04, 4.89901986e-04, 4.89590216e-04, 2.80502325e-03,
#        4.89649527e-04, 3.74613567e-03, 1.01187887e-03, 2.42784827e-03,
#        7.48047897e-04, 2.53062969e-03, 4.07652130e-03, 1.50840052e-03,
#        7.74768677e-07, 2.59079607e-02, 7.74588552e-04, 1.36449072e-02,
#        3.18606870e-03, 1.09727891e-02, 5.37790339e-03, 1.83546902e-02]), 'param_criterion': masked_array(data=['squared_error', 'squared_error', 'squared_error',
#                    'squared_error', 'squared_error', 'squared_error',
#                    'absolute_error', 'absolute_error', 'absolute_error',
#                    'absolute_error', 'absolute_error', 'absolute_error',
#                    'friedman_mse', 'friedman_mse', 'friedman_mse',
#                    'friedman_mse', 'friedman_mse', 'friedman_mse',
#                    'poisson', 'poisson', 'poisson', 'poisson', 'poisson',
#                    'poisson'],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False],
#        fill_value='?',
#             dtype=object), 'param_max_features': masked_array(data=[None, None, 'sqrt', 'sqrt', 'log2', 'log2', None, None,
#                    'sqrt', 'sqrt', 'log2', 'log2', None, None, 'sqrt',
#                    'sqrt', 'log2', 'log2', None, None, 'sqrt', 'sqrt',
#                    'log2', 'log2'],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False],
#        fill_value='?',
#             dtype=object), 'param_n_estimators': masked_array(data=[10, 100, 10, 100, 10, 100, 10, 100, 10, 100, 10, 100,
#                    10, 100, 10, 100, 10, 100, 10, 100, 10, 100, 10, 100],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False],
#        fill_value=999999), 'params': [{'criterion': 'squared_error', 'max_features': None, 'n_estimators': 10}, {'criterion': 'squared_error', 'max_features': None, 'n_estimators': 100}, {'criterion': 'squared_error', 'max_features': 'sqrt', 'n_estimators': 10}, {'criterion': 'squared_error', 'max_features': 'sqrt', 'n_estimators': 100}, {'criterion': 'squared_error', 'max_features': 'log2', 'n_estimators': 10}, {'criterion': 'squared_error', 'max_features': 'log2', 'n_estimators': 100}, {'criterion': 'absolute_error', 'max_features': None, 'n_estimators': 10}, {'criterion': 'absolute_error', 'max_features': None, 'n_estimators': 100}, {'criterion': 'absolute_error', 'max_features': 'sqrt', 'n_estimators': 10}, {'criterion': 'absolute_error', 'max_features': 'sqrt', 'n_estimators': 100}, {'criterion': 'absolute_error', 'max_features': 'log2', 'n_estimators': 10}, {'criterion': 'absolute_error', 'max_features': 'log2', 'n_estimators': 100}, {'criterion': 'friedman_mse', 'max_features': None, 'n_estimators': 10}, {'criterion': 'friedman_mse', 'max_features': None, 'n_estimators': 100}, {'criterion': 'friedman_mse', 'max_features': 'sqrt', 'n_estimators': 10}, {'criterion': 'friedman_mse', 'max_features': 'sqrt', 'n_estimators': 100}, {'criterion': 'friedman_mse', 'max_features': 'log2', 'n_estimators': 10}, {'criterion': 'friedman_mse', 'max_features': 'log2', 'n_estimators': 100}, {'criterion': 'poisson', 'max_features': None, 'n_estimators': 10}, {'criterion': 'poisson', 'max_features': None, 'n_estimators': 100}, {'criterion': 'poisson', 'max_features': 'sqrt', 'n_estimators': 10}, {'criterion': 'poisson', 'max_features': 'sqrt', 'n_estimators': 100}, {'criterion': 'poisson', 'max_features': 'log2', 'n_estimators': 10}, {'criterion': 'poisson', 'max_features': 'log2', 'n_estimators':
criterion': 'squared_error', 'max_features': 'sqrt', 'n_estimators': 100}:

# %%
table=pd.DataFrame.from_dict(re)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.092402      0.003541         0.009924    6.477245e-04
# 1        0.816337      0.010005         0.029183    3.185357e-03
# 2        0.074553      0.001355         0.010994    2.096534e-03
# 3        0.630880      0.030304         0.026742    7.321699e-04
# 4        0.085059      0.016464         0.009160    4.229593e-04
# 5        0.609175      0.007219         0.025385    4.899020e-04
# 6        0.351566      0.005564         0.008595    4.895902e-04
# 7        3.654088      0.034774         0.028552    2.805023e-03
# 8        0.250644      0.031995         0.008594    4.896495e-04
# 9        2.154338      0.032348         0.028082    3.746136e-03
# 10       0.218660      0.007184         0.009572    1.011879e-03
# 11       2.386096      0.140175         0.034370    2.427848e-03
# 12       0.131374      0.037570         0.008195    7.480479e-04
# 13       0.886346      0.026854         0.030480    2.530630e-03
# 14       0.080550      0.005311         0.012393    4.076521e-03
# 15       0.654039      0.017945         0.028890    1.508401e-03
# 16       0.069756      0.001719         0.008995    7.747687e-07
# 17       0.797977      0.117971         0.062147    2.590796e-02
# 18       0.204876      0.021539         0.009477    7.745886e-04
# 19       1.893179      0.049351         0.042532    1.364491e-02
# 20       0.223368      0.056068         0.012792    3.186069e-03
# 21       1.392423      0.023468         0.043773    1.097279e-02
# 22       0.178180      0.019879         0.015191    5.377903e-03
# 23       1.572752      0.146627         0.041277    1.835469e-02
#
#    param_criterion param_max_features  param_n_estimators  \
# 0    squared_error               None                  10
# 1    squared_error               None                 100
# 2    squared_error               sqrt                  10
# 3    squared_error               sqrt                 100
# 4    squared_error               log2                  10
# 5    squared_error               log2                 100
# 6   absolute_error               None                  10
# 7   absolute_error               None                 100
# 8   absolute_error               sqrt                  10
# 9   absolute_error               sqrt                 100
# 10  absolute_error               log2                  10
# 11  absolute_error               log2                 100
# 12    friedman_mse               None                  10
# 13    friedman_mse               None                 100
# 14    friedman_mse               sqrt                  10
# 15    friedman_mse               sqrt                 100
# 16    friedman_mse               log2                  10
# 17    friedman_mse               log2                 100
# 18         poisson               None                  10
# 19         poisson               None                 100
# 20         poisson               sqrt                  10
# 21         poisson               sqrt                 100
# 22         poisson               log2                  10
# 23         poisson               log2                 100
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.839232
# 1   {'criterion': 'squared_error', 'max_features':...           0.849058
# 2   {'criterion': 'squared_error', 'max_features':...           0.835310
# 3   {'criterion': 'squared_error', 'max_features':...           0.858760
# 4   {'criterion': 'squared_error', 'max_features':...           0.834243
# 5   {'criterion': 'squared_error', 'max_features':...           0.858587
# 6   {'criterion': 'absolute_error', 'max_features'...           0.814657
# 7   {'criterion': 'absolute_error', 'max_features'...           0.837394
# 8   {'criterion': 'absolute_error', 'max_features'...           0.854070
# 9   {'criterion': 'absolute_error', 'max_features'...           0.857934
# 10  {'criterion': 'absolute_error', 'max_features'...           0.843382
# 11  {'criterion': 'absolute_error', 'max_features'...           0.854551
# 12  {'criterion': 'friedman_mse', 'max_features': ...           0.844504
# 13  {'criterion': 'friedman_mse', 'max_features': ...           0.845363
# 14  {'criterion': 'friedman_mse', 'max_features': ...           0.849123
# 15  {'criterion': 'friedman_mse', 'max_features': ...           0.856689
# 16  {'criterion': 'friedman_mse', 'max_features': ...           0.814703
# 17  {'criterion': 'friedman_mse', 'max_features': ...           0.858915
# 18  {'criterion': 'poisson', 'max_features': None,...           0.843979
# 19  {'criterion': 'poisson', 'max_features': None,...           0.845190
# 20  {'criterion': 'poisson', 'max_features': 'sqrt...           0.839637
# 21  {'criterion': 'poisson', 'max_features': 'sqrt...           0.856651
# 22  {'criterion': 'poisson', 'max_features': 'log2...           0.841834
# 23  {'criterion': 'poisson', 'max_features': 'log2...           0.859032
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.764241           0.844163           0.791550
# 1            0.769080           0.858417           0.817033
# 2            0.757920           0.853871           0.803283
# 3            0.781352           0.860108           0.828678
# 4            0.746987           0.848466           0.804970
# 5            0.782944           0.861199           0.830296
# 6            0.767625           0.817158           0.804468
# 7            0.768452           0.850605           0.822850
# 8            0.759918           0.826031           0.802878
# 9            0.775172           0.859341           0.828944
# 10           0.764177           0.840523           0.808537
# 11           0.777325           0.856849           0.826442
# 12           0.768062           0.830507           0.816587
# 13           0.778794           0.859915           0.817761
# 14           0.769953           0.848162           0.818495
# 15           0.779715           0.858890           0.831225
# 16           0.753166           0.847258           0.807533
# 17           0.782263           0.857509           0.829924
# 18           0.761673           0.854416           0.813458
# 19           0.771354           0.856494           0.820025
# 20           0.781364           0.852094           0.814096
# 21           0.784523           0.861501           0.825272
# 22           0.764217           0.832801           0.814744
# 23           0.777745           0.860842           0.827971
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.834763         0.814790        0.031478               20
# 1            0.836620         0.826042        0.031672               10
# 2            0.834307         0.816938        0.033683               18
# 3            0.842450         0.834270        0.028865                1
# 4            0.837549         0.814443        0.036670               21
# 5            0.838051         0.834215        0.028217                2
# 6            0.830275         0.806837        0.021262               24
# 7            0.836361         0.823133        0.028716               15
# 8            0.821038         0.812787        0.031116               22
# 9            0.842091         0.832696        0.030849                7
# 10           0.834533         0.818231        0.029702               17
# 11           0.841370         0.831307        0.029092                8
# 12           0.835520         0.819036        0.027042               16
# 13           0.836605         0.827688        0.027999                9
# 14           0.832337         0.823614        0.029104               12
# 15           0.841477         0.833599        0.028789                5
# 16           0.834050         0.811342        0.032298               23
# 17           0.840286         0.833779        0.027950                3
# 18           0.842407         0.823187        0.033632               14
# 19           0.837088         0.826030        0.029809               11
# 20           0.828781         0.823195        0.024369               13
# 21           0.840401         0.833670        0.027691                4
# 22           0.823858         0.815491        0.027178               19
# 23           0.838561         0.832830        0.030206                6

# %%
age=float(input("AGE:"))
bmi=float(input("BMI:"))
children=float(input("Children:"))
gender=int(input("Gender Male 0 or 1:"))
smoker=int(input("Smoker Yes 0 or 1 :"))
# Out:
# AGE: 32
# BMI: 43
# Children: 2
# Gender Male 0 or 1: 0
# Smoker Yes 0 or 1 : 1

# %%
Prediction=grid.predict([[age,bmi,children,gender,smoker]])
print("Future Predocion{}".format(Prediction))
# Out:
# Future Predocion[45840.1814154]
# C:\Anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(

# %%
Prediction=grid.predict([[32,43,2,0,1]])
Prediction
# Out:
# C:\Anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# array([45840.1814154])
